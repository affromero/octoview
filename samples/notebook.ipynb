# %% [markdown]
# # Notebook sample
#
# GitHub renders notebooks but **strips the outputs of interactive cells**. octoview keeps them: below are a live **Plotly** chart output and an image output, with syntax-highlighted code cells.

# %%
print('training complete, 3 epochs')
# Out:
# training complete, 3 epochs

# %%
import plotly.express as px
px.bar(df, x='class', y='count')  # interactive; GitHub drops it, octoview keeps it

# %%
fig.savefig('loss.png')  # image/png output
