# %% [markdown]
# # Notebook sample
#
# GitHub renders notebooks but **strips interactive outputs**. octoview keeps them: the plot cell below is a live `text/html` output that runs its own script.

# %%
print('training complete — 3 epochs')
# Out:
# training complete — 3 epochs

# %%
import plotly.express as px  # in a real notebook this emits interactive text/html
# (sample uses a tiny inline chart to demonstrate live output rendering)
# Out:
# <div id="p" style="font:14px sans-serif;padding:12px">rendering…</div>
# <script>
#   var d=document.getElementById('p');
#   var bars=[5,9,3,7,10,4].map(function(v){return '<div style=\"display:inline-block;width:22px;margin:2px;height:'+(v*12)+'px;background:#2ea043;vertical-align:bottom\"></div>';}).join('');
#   d.innerHTML='<b>interactive output \u2713</b><br>'+bars;
# </script>
