# %% [markdown]
# # Notebook sample
#
# GitHub renders notebooks but **strips the outputs of interactive cells**. octoview keeps them: below are a `text/html` chart output and an image output.

# %%
print('training complete, 3 epochs')
# Out:
# training complete, 3 epochs

# %%
import plotly.express as px  # a real notebook emits interactive text/html here
px.bar(df, x='class', y='count')
# Out:
# <div style="font:13px -apple-system,sans-serif;padding:10px;color:#1f2328"><b>Interactive output</b> (GitHub strips this; octoview keeps it)<svg width="380" height="140" viewBox="0 0 380 140" role="img" aria-label="bars"><rect width="380" height="140" fill="#fff"/><rect x="20" y="40" width="40" height="90" fill="#2ea043" opacity="0.5"/><text x="40" y="128" font-size="10" fill="#57606a" text-anchor="middle">c0</text><rect x="80" y="70" width="40" height="60" fill="#2ea043" opacity="0.6"/><text x="100" y="128" font-size="10" fill="#57606a" text-anchor="middle">c1</text><rect x="140" y="25" width="40" height="105" fill="#2ea043" opacity="0.7"/><text x="160" y="128" font-size="10" fill="#57606a" text-anchor="middle">c2</text><rect x="200" y="85" width="40" height="45" fill="#2ea043" opacity="0.8"/><text x="220" y="128" font-size="10" fill="#57606a" text-anchor="middle">c3</text><rect x="260" y="55" width="40" height="75" fill="#2ea043" opacity="0.9"/><text x="280" y="128" font-size="10" 
# ...

# %%
fig.savefig('loss.png')  # image/png output

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_scatter(x=list(range(8)), y=[2.31, 1.62, 1.18, 0.94, 0.81, 0.74, 0.70, 0.68], mode='lines+markers', name='train loss')
fig.add_bar(x=list(range(8)), y=[0.41, 0.55, 0.63, 0.68, 0.71, 0.73, 0.74, 0.75], name='val accuracy', opacity=0.5)
fig.update_layout(title='Live Plotly chart (octoview renders this interactive)', height=320)
fig.show()
# Out:
# <div>Plotly chart (requires script execution — octoview renders the MIME bundle instead)</div>
